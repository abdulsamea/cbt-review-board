# %%
import os
import sys
from pathlib import Path

project_root = str(Path().resolve().parent)

# Insert the project root path at the beginning of the system path
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(f"Project root added to path: {project_root}")

# %%
from graph.supervisor import compile_supervisor_graph
from IPython.display import Image, display

cbt_review_graph_image = compile_supervisor_graph().get_graph().draw_mermaid_png()
display(Image(cbt_review_graph_image))
# Out:
# error connecting in 'pool-2': failed to resolve host 'db.cnfqixktejxoawubtvlt.supabase.co': [Errno 11001] getaddrinfo failed
# error connecting in 'pool-1': failed to resolve host 'db.cnfqixktejxoawubtvlt.supabase.co': [Errno 11001] getaddrinfo failed
# error connecting in 'pool-2': failed to resolve host 'db.cnfqixktejxoawubtvlt.supabase.co': [Errno 11001] getaddrinfo failed
# error connecting in 'pool-1': failed to resolve host 'db.cnfqixktejxoawubtvlt.supabase.co': [Errno 11001] getaddrinfo failed
# error connecting in 'pool-1': failed to resolve host 'db.cnfqixktejxoawubtvlt.supabase.co': [Errno 11001] getaddrinfo failed
# error connecting in 'pool-1': failed to resolve host 'db.cnfqixktejxoawubtvlt.supabase.co': [Errno 11001] getaddrinfo failed
# error connecting in 'pool-2': failed to resolve host 'db.cnfqixktejxoawubtvlt.supabase.co': [Errno 11001] getaddrinfo failed
# error connecting in 'pool-2': failed to resolve host 'db.cnfqixktejxoawubtvlt.supabase.co': [Errno 11001] getaddrinfo failed
# error connecting in 'pool-2': failed to resolve host 'db.cnfqixktejxoawubtvlt.supabase.co': [Errno 11001] getaddrinfo failed
# error connecting in 'pool-1': failed to resolve host 'db.cnfqixktejxoawubtvlt.supabase.co': [Errno 11001] getaddrinfo failed
# error connecting in 'pool-2': failed to resolve host 'db.cnfqixktejxoawubtvlt.supabase.co': [Errno 11001] getaddrinfo failed
# error connecting in 'pool-1': failed to resolve host 'db.cnfqixktejxoawubtvlt.supabase.co': [Errno 11001] getaddrinfo failed
# error connecting in 'pool-1': failed to resolve host 'db.cnfqixktejxoawubtvlt.supabase.co': [Errno 11001] getaddrinfo failed
# error connecting in 'pool-1': failed to resolve host 'db.cnfqixktejxoawubtvlt.supabase.co': [Errno 11001] getaddrinfo failed
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\urllib3\response.py:899, in HTTPResponse._error_catcher(self)
#     898 try:
# --> 899     yield
#     901 except SocketTimeout as e:
#     902     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     903     # there is yet no clean way to get at it from this context.
#
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\urllib3\response.py:1024, in HTTPResponse._raw_read(self, amt, read1)
#    1023 with self._error_catcher():
# -> 1024     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#    1025     if amt is not None and amt != 0 and not data:
#    1026         # Platform-specific: Buggy versions of Python.
#    1027         # Close the connection when no data is returned
#    (...)   1032         # not properly close the connection in all cases. There is
#    1033         # no harm in redundantly calling close.
#
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\urllib3\response.py:1007, in HTTPResponse._fp_read(self, amt, read1)
#    1005 else:
#    1006     # StringIO doesn't like amt=None
# -> 1007     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~\anaconda3\Lib\http\client.py:479, in HTTPResponse.read(self, amt)
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#
# File ~\anaconda3\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# File ~\anaconda3\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File ~\anaconda3\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     819 try:
# --> 820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
#
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\urllib3\response.py:1253, in HTTPResponse.stream(self, amt, decode_content)
#    1248 while (
#    1249     not is_fp_closed(self._fp)
#    1250     or len(self._decoded_buffer) > 0
#    1251     or (self._decoder and self._decoder.has_unconsumed_tail)
#    1252 ):
# -> 1253     data = self.read(amt=amt, decode_content=decode_content)
#    1255     if data:
#
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\urllib3\response.py:1108, in HTTPResponse.read(self, amt, decode_content, cache_content)
#    1106         return self._decoded_buffer.get(amt)
# -> 1108 data = self._raw_read(amt)
#    1110 flush_decoder = amt is None or (amt != 0 and not data)
#
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\urllib3\response.py:1023, in HTTPResponse._raw_read(self, amt, read1)
#    1021 fp_closed = getattr(self._fp, "closed", False)
# -> 1023 with self._error_catcher():
#    1024     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#
# File ~\anaconda3\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\urllib3\response.py:904, in HTTPResponse._error_catcher(self)
#     901 except SocketTimeout as e:
#     902     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     903     # there is yet no clean way to get at it from this context.
# --> 904     raise ReadTimeoutError(self._pool, None, "Read timed out.") from e  # type: ignore[arg-type]
#     906 except BaseSSLError as e:
#     907     # FIXME: Is there a better way to differentiate between SSLErrors?
#
# ReadTimeoutError: HTTPSConnectionPool(host='mermaid.ink', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\langchain_core\runnables\graph_mermaid.py:452, in _render_mermaid_using_api(mermaid_syntax, output_file_path, background_color, file_type, max_retries, retry_delay, proxies, base_url)
#     451 try:
# --> 452     response = requests.get(image_url, timeout=10, proxies=proxies)
#     453     if response.status_code == requests.codes.ok:
#
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)     70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\requests\sessions.py:746, in Session.send(self, request, **kwargs)
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\requests\models.py:902, in Response.content(self)
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\requests\models.py:826, in Response.iter_content.<locals>.generate()
#     825 except ReadTimeoutError as e:
# --> 826     raise ConnectionError(e)
#     827 except SSLError as e:
#
# ConnectionError: HTTPSConnectionPool(host='mermaid.ink', port=443): Read timed out.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 from graph.supervisor import compile_supervisor_graph
#       2 from IPython.display import Image, display
# ----> 4 cbt_review_graph_image = compile_supervisor_graph().get_graph().draw_mermaid_png()
#       5 display(Image(cbt_review_graph_image))
#
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\langchain_core\runnables\graph.py:693, in Graph.draw_mermaid_png(self, curve_style, node_colors, wrap_label_n_words, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, frontmatter_config, base_url, proxies)
#     683 from langchain_core.runnables.graph_mermaid import (  # noqa: PLC0415
#     684     draw_mermaid_png,
#     685 )
#     687 mermaid_syntax = self.draw_mermaid(
#     688     curve_style=curve_style,
#     689     node_colors=node_colors,
#     690     wrap_label_n_words=wrap_label_n_words,
#     691     frontmatter_config=frontmatter_config,
#     692 )
# --> 693 return draw_mermaid_png(
#     694     mermaid_syntax=mermaid_syntax,
#     695     output_file_path=output_file_path,
#     696     draw_method=draw_method,
#     697     background_color=background_color,
#     698     padding=padding,
#     699     max_retries=max_retries,
#     700     retry_delay=retry_delay,
#     701     proxies=proxies,
#     702     base_url=base_url,
#     703 )
#
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\langchain_core\runnables\graph_mermaid.py:312, in draw_mermaid_png(mermaid_syntax, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, base_url, proxies)
#     306     img_bytes = asyncio.run(
#     307         _render_mermaid_using_pyppeteer(
#     308             mermaid_syntax, output_file_path, background_color, padding
#     309         )
#     310     )
#     311 elif draw_method == MermaidDrawMethod.API:
# --> 312     img_bytes = _render_mermaid_using_api(
#     313         mermaid_syntax,
#     314         output_file_path=output_file_path,
#     315         background_color=background_color,
#     316         max_retries=max_retries,
#     317         retry_delay=retry_delay,
#     318         base_url=base_url,
#     319         proxies=proxies,
#     320     )
#     321 else:
#     322     supported_methods = ", ".join([m.value for m in MermaidDrawMethod])
#
# File c:\codebase\cbt-review-board\.venv\Lib\site-packages\langchain_core\runnables\graph_mermaid.py:487, in _render_mermaid_using_api(mermaid_syntax, output_file_path, background_color, file_type, max_retries, retry_delay, proxies, base_url)
#     482         else:
#     483             msg = (
#     484                 f"Failed to reach {base_url} API while trying to render "
#     485                 f"your graph after {max_retries} retries. "
#     486             ) + error_msg_suffix
# --> 487             raise ValueError(msg) from e
#     489 # This should not be reached, but just in case
#     490 msg = (
#     491     f"Failed to reach {base_url} API while trying to render "
#     492     f"your graph after {max_retries} retries. "
#     493 ) + error_msg_suffix
#
# ValueError: Failed to reach https://mermaid.ink API while trying to render your graph after 1 retries. To resolve this issue:
# 1. Check your internet connection and try again
# 2. Try with higher retry settings: `draw_mermaid_png(..., max_retries=5, retry_delay=2.0)`
# 3. Use the Pyppeteer rendering method which will render your graph locally in a browser: `draw_mermaid_png(..., draw_method=MermaidDrawMethod.PYPPETEER)`
# error connecting in 'pool-1': failed to resolve host 'db.cnfqixktejxoawubtvlt.supabase.co': [Errno 11001] getaddrinfo failed
