# %%
import os
import sys
from pathlib import Path

project_root = str(Path().resolve().parent)

# Insert the project root path at the beginning of the system path
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(f"Project root added to path: {project_root}")
# Out:
# Project root added to path: C:\Users\abdul_tyym3hn\Downloads\cbt-review-board

# %%
from graph.supervisor import compile_supervisor_graph
from IPython.display import Image, display

cbt_review_graph_image = compile_supervisor_graph().get_graph().draw_mermaid_png()
display(Image(cbt_review_graph_image))
# Out:
# Attempting to initialize SQLite Checkpointer at: C:\Users\abdul_tyym3hn\Downloads\cbt-review-board\cbt_review_board.sqlite
# SQLite Checkpointer initialized successfully. Persistence is ON.
# Attempting to initialize SQLite Checkpointer at: C:\Users\abdul_tyym3hn\Downloads\cbt-review-board\cbt_review_board.sqlite
# SQLite Checkpointer initialized successfully. Persistence is ON.
